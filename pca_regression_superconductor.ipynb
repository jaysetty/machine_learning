# %% [markdown]
# # Example of PCA on a Regression Problem

# %% [markdown]
# Dataset used is from UCI Superconductivity data
#
# http://archive.ics.uci.edu/ml/datasets/Superconductivty+Data

# %%
# %matplotlib inline

# %%
import numpy as np
import pandas as pd
from scipy.stats import zscore
from sklearn.metrics import accuracy_score, mean_squared_error

# %%
import os
os.getcwd()
# Out:
# '/Users/Apple/Desktop/machine_learning/PCA'

# %%
path0 = '/Users/Apple/Desktop/machine_learning/PCA/superconduct/'
supercond_tr = pd.read_csv(path0+'train.csv')
supercond_un = pd.read_csv(path0+'unique_m.csv')

# %%
supercond_tr.head()
# Out:
#    number_of_elements  mean_atomic_mass  wtd_mean_atomic_mass  \
# 0                   4         88.944468             57.862692
# 1                   5         92.729214             58.518416
# 2                   4         88.944468             57.885242
# 3                   4         88.944468             57.873967
# 4                   4         88.944468             57.840143
#
#    gmean_atomic_mass  wtd_gmean_atomic_mass  entropy_atomic_mass  \
# 0          66.361592              36.116612             1.181795
# 1          73.132787              36.396602             1.449309
# 2          66.361592              36.122509             1.181795
# 3          66.361592              36.119560             1.181795
# 4          66.361592              36.110716             1.181795
#
#    wtd_entropy_atomic_mass  range_atomic_mass  wtd_range_atomic_mass  \
# 0                 1.062396          122.90607              31.794921
# ...

# %%
supercond_tr.shape
# Out:
# (21263, 82)

# %%
supercond_tr.describe()
# Out:
#        number_of_elements  mean_atomic_mass  wtd_mean_atomic_mass  \
# count        21263.000000      21263.000000          21263.000000
# mean             4.115224         87.557631             72.988310
# std              1.439295         29.676497             33.490406
# min              1.000000          6.941000              6.423452
# 25%              3.000000         72.458076             52.143839
# 50%              4.000000         84.922750             60.696571
# 75%              5.000000        100.404410             86.103540
# max              9.000000        208.980400            208.980400
#
#        gmean_atomic_mass  wtd_gmean_atomic_mass  entropy_atomic_mass  \
# count       21263.000000           21263.000000         21263.000000
# mean           71.290627              58.539916             1.165608
# std            31.030272              36.651067             0.364930
# min             5.320573               1.960849             0.000000
# ...

# %%
supercond_tr_x = supercond_tr.iloc[:,:81]
supercond_tr_y = supercond_tr.critical_temp

# %%
supercond_tr_x.head()
# Out:
#    number_of_elements  mean_atomic_mass  wtd_mean_atomic_mass  \
# 0                   4         88.944468             57.862692
# 1                   5         92.729214             58.518416
# 2                   4         88.944468             57.885242
# 3                   4         88.944468             57.873967
# 4                   4         88.944468             57.840143
#
#    gmean_atomic_mass  wtd_gmean_atomic_mass  entropy_atomic_mass  \
# 0          66.361592              36.116612             1.181795
# 1          73.132787              36.396602             1.449309
# 2          66.361592              36.122509             1.181795
# 3          66.361592              36.119560             1.181795
# 4          66.361592              36.110716             1.181795
#
#    wtd_entropy_atomic_mass  range_atomic_mass  wtd_range_atomic_mass  \
# 0                 1.062396          122.90607              31.794921
# ...

# %%
supercond_tr_y.head()
# Out:
# 0    29.0
# 1    26.0
# 2    19.0
# 3    22.0
# 4    23.0
# Name: critical_temp, dtype: float64

# %%
supercond_tr_scaled = supercond_tr_x.apply(zscore)

# %%
supercond_tr_scaled.head()
# Out:
#    number_of_elements  mean_atomic_mass  wtd_mean_atomic_mass  \
# 0           -0.080058          0.046733             -0.451651
# 1            0.614744          0.174269             -0.432071
# 2           -0.080058          0.046733             -0.450978
# 3           -0.080058          0.046733             -0.451314
# 4           -0.080058          0.046733             -0.452324
#
#    gmean_atomic_mass  wtd_gmean_atomic_mass  entropy_atomic_mass  \
# 0          -0.158850              -0.611819             0.044358
# 1           0.059368              -0.604180             0.777430
# 2          -0.158850              -0.611658             0.044358
# 3          -0.158850              -0.611739             0.044358
# 4          -0.158850              -0.611980             0.044358
#
#    wtd_entropy_atomic_mass  range_atomic_mass  wtd_range_atomic_mass  \
# 0                -0.003707           0.133725              -0.053039
# ...

# %%
from sklearn.decomposition import PCA
pca = PCA(n_components=15)
pca.fit_transform(supercond_tr_scaled)
supercond_tr_pca = pca.fit_transform(supercond_tr_scaled)

# %%
# Let us investigate the proportion 
# of variance explained and the elbow method
# pca.get_covariance()
pca.explained_variance_
# len(pca.explained_variance_)
# Out:
# array([31.53623973,  8.49098846,  7.71253473,  6.40556262,  4.76479223,
#         3.06872281,  2.93416164,  2.51687507])

# %%
pca.explained_variance_ratio_
# Out:
# array([0.38931798, 0.10482209, 0.095212  , 0.0790773 , 0.05882183,
#        0.03788369, 0.03622251, 0.03107107])

# %%
pca.explained_variance_ratio_.cumsum()
# Out:
# array([0.38931798, 0.49414007, 0.58935207, 0.66842937, 0.7272512 ,
#        0.76513489, 0.8013574 , 0.83242847])

# %%
# Let us investigate the performance of the models

from sklearn.tree import DecisionTreeRegressor
DT = DecisionTreeRegressor(max_depth=6)
DT.fit(supercond_tr_scaled,supercond_tr_y)
# Out:
# DecisionTreeRegressor(criterion='mse', max_depth=6, max_features=None,
#            max_leaf_nodes=None, min_impurity_decrease=0.0,
#            min_impurity_split=None, min_samples_leaf=1,
#            min_samples_split=2, min_weight_fraction_leaf=0.0,
#            presort=False, random_state=None, splitter='best')

# %%
rmse_without_pca = mean_squared_error(supercond_tr_y, DT.predict(supercond_tr_scaled))
rmse_without_pca
# Out:
# 221.09844369292645

# %%
from sklearn.tree import DecisionTreeRegressor
DT_pca = DecisionTreeRegressor(max_depth=6)
DT_pca.fit(supercond_tr_pca,supercond_tr_y)
# Out:
# DecisionTreeRegressor(criterion='mse', max_depth=6, max_features=None,
#            max_leaf_nodes=None, min_impurity_decrease=0.0,
#            min_impurity_split=None, min_samples_leaf=1,
#            min_samples_split=2, min_weight_fraction_leaf=0.0,
#            presort=False, random_state=None, splitter='best')

# %%
rmse_with_pca = mean_squared_error(supercond_tr_y, DT_pca.predict(supercond_tr_pca))
rmse_with_pca
# Out:
# 256.8309833772047

# %%
DT_pca.predict(supercond_tr_pca)

# %%
DT.predict(supercond_tr_scaled)

# %%
# Grid Search on PCA?, Can we merge the second file and then apply PCA
